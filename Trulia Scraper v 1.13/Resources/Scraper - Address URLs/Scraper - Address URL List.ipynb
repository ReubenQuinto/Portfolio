# %% [markdown]
# # Create Functions

# %% [raw]
# ## This function saves a designated URL to .txt
#
# from bs4 import BeautifulSoup as bs
# from splinter import Browser
#
# def init_browser():
#     # Chrome driver
#     executable_path = {"executable_path": "chromedriver"}
#     return Browser("chrome", **executable_path, headless=False)
#
# # Random Sleep Variable Time
# def rand_sleep():
#     time.sleep(random.randint(15,30))
#
# # Save website to txt
# def sandbox_scrape_soup(url):
#
#     # Initialize: Browser
#     browser = init_browser()
#
#     browser.visit(url)
#
#     # Create: Soup obj
#     html = browser.html
#     soup = bs(html, "html.parser")
#
#     # Create and Save: Store the soup obj into a text file (The purpose is to bypass: Google Image Verification Security)
#     # This text file will be overwritten each time this function is called
#     f = open("staging_soup.txt", "w")
#     f.write(str(soup))
#     f.close()
#
#     browser.quit()
#
#
# sandbox_scrape_soup("https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92603/Bethany_Dr/")

# %%
# Import: Dependencies
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
import random
import time

# Create: MISC Functions

def init_browser():
    # Chrome driver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# Random Sleep Variable Time
def rand_sleep():
    time.sleep(random.randint(60,240))
    
# Create: MAIN Functions
   
# Testing Function: Save website to txt > scrape the .txt file
def scrape_addr_urls(url, idx):
    
    # Initialize: Browser
    browser = init_browser()
    
    # Visiting: Browser
    browser.visit(url)
    
    # Create: Soup obj
    html = browser.html
    soup = bs(html, "html.parser")
    
    try:
        # Create and Save: Store the soup obj into a text file (The purpose is to bypass: Google Image Verification Security)
        # This text file will be overwritten each time this function is called
        f = open("staging_soup.txt", "w")
        f.write(str(soup))
        f.close()
    except:
        pass
       
    # Requirement to bypass Google Image Verification Secuirty
    rand_sleep()
    
    # Closing: Browser
    browser.quit()
    
    ########## Begin Scrape: Scraping the text file (Not the URL)
    
    try:
        # Create: A soup obj from the .txt file mentioned above
        f = open("staging_soup.txt")
        soup = bs(f, "html.parser")
    except:
        pass

    try:
        # Create: Target obj
        target = soup.find_all("ul", class_="all-properties")[0].find_all("li")
    except:
        pass

    df_street_url_3 = pd.read_csv("Address URL List - PreProcessing (2 of 2).csv", header=0, names=["zip",
                                                                                                    "street",
                                                                                                    "units",
                                                                                                    "type",
                                                                                                    "url_addr"])
    # Append: URL addresses
    for y in range(len(target)):

        # Initialize: Python dictionary (To store the scraped data)
        dict_url_addr = {}

        zip_cd = df_street_url_3["zip"][idx],
        street = df_street_url_3["street"][idx],
        units = df_street_url_3["units"][idx],
        house_type = df_street_url_3["type"][idx],
        url_addr = target[y].a.get("href")

        # Add and Clean: Scraped data to dict
        dict_url_addr = {
            "zip": "".join(str(zip_cd)).replace("(","").replace(",","").replace(")",""),
            "street": "".join(str(street)).replace("(","").replace(",","").replace(")","").replace("'",""),
            "units": "".join(str(units)).replace("(","").replace(",","").replace(")",""),
            "type": "".join(str(house_type)).replace("(","").replace(",","").replace(")","").replace("'",""),
            "url_addr": "".join(str(url_addr)).replace("(","").replace(",","").replace(")","")
        }

        df_street_url_2 = pd.read_csv("Address URL List - FINAL.csv")

        # Append: Dataframe to Database
        df_street_url_2 = df_street_url_2.append(dict_url_addr, ignore_index=True)

        # Save: Info to Dataframe
        df_street_url_2.to_csv("Address URL List - FINAL.csv", index=False, columns=["zip",
                                                                                     "street",
                                                                                     "units",
                                                                                     "type",
                                                                                     "url_addr"
                                                                                    ])

# %% [markdown]
# # Read in URL Links

# %%
# Create: A DF to read in the "staging_address.csv"
df_street_url = pd.read_csv("Address URL List - PreProcessing (2 of 2).csv")

# Initialize: List
street_url_list = []

# Scrape: Address + append to address_url_list = []
for i in range(len(df_street_url)):
    street_url_list.append(df_street_url["url"][i])

for i in range(len(df_street_url)):
    print(f'Row: {str(i + 1)} | URL: {street_url_list[i]}')
# Out:
# Row: 1 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Triana/
# Row: 2 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Preston/
# Row: 3 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Modena/
# Row: 4 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Cunningham/
# Row: 5 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Gray_Dove/
# Row: 6 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Pembroke/
# Row: 7 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Sutton/
# Row: 8 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Yellow_Daisy/
# Row: 9 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Monticello/
# Row: 10 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Field_Poppy/
# Row: 11 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Bennington/
# Row: 12 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Diamante/
# Row: 13 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Carson/
# Row: 14 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Statuary/
# Row: 15 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Wheeler/
# Row: 16 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Marblehead/
# Row: 17 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/New_Dawn/
# Row: 18 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Garden_Gate_Ln/
# Row: 19 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Bridgeport_Rd/
# Row: 20 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Renata/
# Row: 21 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Archipelago_Dr/
# Row: 22 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Marisol/
# Row: 23 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Clermont/
# Row: 24 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Vernon/
# Row: 25 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Avignon/
# Row: 26 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Castellina_Dr/
# Row: 27 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Harcourt/
# Row: 28 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Coral_Reef/
# Row: 29 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Highridge_Way/
# Row: 30 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Via_Coyote/
# Row: 31 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Jasper_Hill_Rd/
# Row: 32 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Via_Candelaria/
# Row: 33 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Mill_Stream_Rd/
# Row: 34 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Frontier_St/
# Row: 35 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Dornoch_Way/
# Row: 36 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Porter_Ranch_Rd/
# Row: 37 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Panorama/
# Row: 38 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Gingham_St/
# Row: 39 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Sonora_St/
# Row: 40 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Georgia_St/
# Row: 41 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Arborwalk_Ln/
# Row: 42 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Severyns_Rd/
# Row: 43 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Charleston_St/
# Row: 44 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Madison_St/
# Row: 45 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Voyager_Dr/
# Row: 46 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Wickshire_Ln/
# Row: 47 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Allen/
# Row: 48 | URL: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Bruns_Dr/

# %% [markdown]
# # Execute Main Function via For Loop

# %% [raw]
# # This code is: FOR TESTING
#
# try:
#     # Create: A soup obj from the .txt file mentioned above
#     f = open("staging_soup.txt")
#     soup = bs(f, "html.parser")
# except:
#     pass
#
# try:
#     # Create: Target obj
#     target = soup.find_all("ul", class_="all-properties")[0].find_all("li")
# except:
#     pass
#
# df_street_url_3 = pd.read_csv("Address URL List - PreProcessing (2 of 2).csv", header=0, names=["zip",
#                                                                                                 "street",
#                                                                                                 "units",
#                                                                                                 "type",
#                                                                                                 "url_addr"])
# # Append: URL addresses
# for y in range(len(target)):
#
#     # Initialize: Python dictionary (To store the scraped data)
#     dict_url_addr = {}
#
#     zip_cd = df_street_url_3["zip"][1],
#     street = df_street_url_3["street"][1],
#     units = df_street_url_3["units"][1],
#     house_type = df_street_url_3["type"][1],
#     url_addr = target[y].a.get("href")
#
#     # Add and Clean: Scraped data to dict
#     dict_url_addr = {
#         "zip": "".join(str(zip_cd)).replace("(","").replace(",","").replace(")",""),
#         "street": "".join(str(street)).replace("(","").replace(",","").replace(")","").replace("'",""),
#         "units": "".join(str(units)).replace("(","").replace(",","").replace(")",""),
#         "type": "".join(str(house_type)).replace("(","").replace(",","").replace(")","").replace("'",""),
#         "url_addr": "".join(str(url_addr)).replace("(","").replace(",","").replace(")","")
#     }
#
# #     df_street_url_2 = pd.read_csv("Address URL List - FINAL.csv")
#
# #     # Append: Dataframe to Database
# #     df_street_url_2 = df_street_url_2.append(dict_url_addr, ignore_index=True)
#
# #     # Save: Info to Dataframe
# #     df_street_url_2.to_csv("Address URL List - FINAL.csv", index=False, columns=["zip",
# #                                                                                  "street",
# #                                                                                  "units",
# #                                                                                  "type",
# #                                                                                  "url_addr"
# #                                                                                 ])
#
# len(target)

# %%
# This code is: LIVE

counter = 0

for i in range(len(street_url_list)):
    scrape_addr_urls(street_url_list[i], i)
    counter = counter + 1
    print("Scrape no: " + str(counter) + " completed. | URL processed: " + str(street_url_list[i]) + " | " + str(len(street_url_list) - i) + " remaining.")

print("Scrape Batch Completed")
# Out:
# Scrape no: 1 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Triana/ | 48 remaining.
# Scrape no: 2 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Preston/ | 47 remaining.
# Scrape no: 3 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Modena/ | 46 remaining.
# Scrape no: 4 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Cunningham/ | 45 remaining.
# Scrape no: 5 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Gray_Dove/ | 44 remaining.
# Scrape no: 6 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Pembroke/ | 43 remaining.
# Scrape no: 7 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Sutton/ | 42 remaining.
# Scrape no: 8 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92618/Yellow_Daisy/ | 41 remaining.
# Scrape no: 9 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Monticello/ | 40 remaining.
# Scrape no: 10 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Field_Poppy/ | 39 remaining.
# Scrape no: 11 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Bennington/ | 38 remaining.
# Scrape no: 12 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Diamante/ | 37 remaining.
# Scrape no: 13 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Carson/ | 36 remaining.
# Scrape no: 14 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Statuary/ | 35 remaining.
# Scrape no: 15 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Wheeler/ | 34 remaining.
# Scrape no: 16 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Marblehead/ | 33 remaining.
# Scrape no: 17 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/New_Dawn/ | 32 remaining.
# Scrape no: 18 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92620/Garden_Gate_Ln/ | 31 remaining.
# Scrape no: 19 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Bridgeport_Rd/ | 30 remaining.
# Scrape no: 20 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Renata/ | 29 remaining.
# Scrape no: 21 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Archipelago_Dr/ | 28 remaining.
# Scrape no: 22 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Marisol/ | 27 remaining.
# Scrape no: 23 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Clermont/ | 26 remaining.
# Scrape no: 24 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Vernon/ | 25 remaining.
# Scrape no: 25 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Avignon/ | 24 remaining.
# Scrape no: 26 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Castellina_Dr/ | 23 remaining.
# Scrape no: 27 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Harcourt/ | 22 remaining.
# Scrape no: 28 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92657/Coral_Reef/ | 21 remaining.
# Scrape no: 29 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Highridge_Way/ | 20 remaining.
# Scrape no: 30 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Via_Coyote/ | 19 remaining.
# Scrape no: 31 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Jasper_Hill_Rd/ | 18 remaining.
# Scrape no: 32 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Via_Candelaria/ | 17 remaining.
# Scrape no: 33 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Mill_Stream_Rd/ | 16 remaining.
# Scrape no: 34 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Frontier_St/ | 15 remaining.
# Scrape no: 35 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Dornoch_Way/ | 14 remaining.
# Scrape no: 36 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Porter_Ranch_Rd/ | 13 remaining.
# Scrape no: 37 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Panorama/ | 12 remaining.
# Scrape no: 38 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92679/Gingham_St/ | 11 remaining.
# Scrape no: 39 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Sonora_St/ | 10 remaining.
# Scrape no: 40 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Georgia_St/ | 9 remaining.
# Scrape no: 41 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Arborwalk_Ln/ | 8 remaining.
# Scrape no: 42 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Severyns_Rd/ | 7 remaining.
# Scrape no: 43 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Charleston_St/ | 6 remaining.
# Scrape no: 44 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Madison_St/ | 5 remaining.
# Scrape no: 45 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Voyager_Dr/ | 4 remaining.
# Scrape no: 46 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Wickshire_Ln/ | 3 remaining.
# Scrape no: 47 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Allen/ | 2 remaining.
# Scrape no: 48 completed. | URL processed: https://www.trulia.com/property-sitemap/CA/Orange-County-06059/92782/Bruns_Dr/ | 1 remaining.
# Scrape Batch Completed
